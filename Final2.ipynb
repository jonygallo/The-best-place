# %% [markdown]
# # Description

# %% [markdown]
# We are looking for the best place to place a bakery

# %% [markdown]
# # Data

# %% [markdown]
# We'll use the location of another bakeries to select the best place in San Isidro, Buenos Aires, Argentina.

# %% [markdown]
# # Import libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# Collecting folium==0.5.0
#   Downloading folium-0.5.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 10.9 MB/s eta 0:00:01
# Collecting branca
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.25.9)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76240 sha256=a887c00c2534af8f95fa4ba6d1b05961d8b8cbe2a4bcae8af36a9dee382f666d
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/b2/2f/2c/109e446b990d663ea5ce9b078b5e7c1a9c45cca91f377080f8
# Successfully built folium
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.5.0
# Folium installed
# Libraries imported.

# %% [markdown]
# # Configure api

# %%
CLIENT_ID = 'VQMGV4XGVVJWY23Y33DIZWWSC03I252BHR0VZC0BGUDDNANK' # your Foursquare ID
CLIENT_SECRET = 'P2LUYORFDKD5I4SBKAEGAGSOO303DZBJVDRQ3EAZWN0WPQ2J' # your Foursquare Secret
ACCESS_TOKEN = '' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 10
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: VQMGV4XGVVJWY23Y33DIZWWSC03I252BHR0VZC0BGUDDNANK
# CLIENT_SECRET:P2LUYORFDKD5I4SBKAEGAGSOO303DZBJVDRQ3EAZWN0WPQ2J

# %% [markdown]
# # Configure address

# %%
address = 'san isidro, buenos aires, argentina'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# -34.4739792 -58.5264866

# %% [markdown]
# # Look for another bakeries in the neighbrood

# %%
search_query = 'panadería'
radius = 30000

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=VQMGV4XGVVJWY23Y33DIZWWSC03I252BHR0VZC0BGUDDNANK&client_secret=P2LUYORFDKD5I4SBKAEGAGSOO303DZBJVDRQ3EAZWN0WPQ2J&ll=-34.4739792,-58.5264866&oauth_token=&v=20180604&query=panadería&radius=30000&limit=10'

# %% [markdown]
# # Get the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '602d459452faab7f2621b302'},
#  'response': {'venues': [{'id': '4cdc19ed22bd721e5a3ff947',
#     'name': 'Panadería Beccar',
#     'location': {'address': '9 de julio 473',
#      'lat': -34.468557542023724,
#      'lng': -58.51071485164477,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -34.468557542023724,
#        'lng': -58.51071485164477}],
#      'distance': 1568,
#      'postalCode': '1642',
#      'cc': 'AR',
#      'city': 'San Isidro',
#      'state': 'Buenos Aires',
#      'country': 'Argentina',
#      'formattedAddress': ['9 de julio 473',
#       '1642 San Isidro',
#       'Buenos Aires',
#       'Argentina']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613579668',
#     'hasPerk': False},
#    {'id': '5d555f1e29e8f70008204566',
#     'name': 'Panaderia',
#     'location': {'lat': -34.474884,
#      'lng': -58.530518,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -34.474884,
#        'lng': -58.530518}],
#      'distance': 383,
#      'postalCode': 'B1642',
#      'cc': 'AR',
#      'city': 'San Isidro',
#      'state': 'Buenos Aires',
#      'country': 'Argentina',
#      'formattedAddress': ['B1642 San Isidro', 'Buenos Aires', 'Argentina']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613579668',
#     'hasPerk': False},
#    {'id': '4c07f824bbc676b095cb45d5',
#     'name': 'PANADERIA - CONFITERIA LA NUEVA ESPERANZA',
#     'location': {'address': 'Sta Marina 1250',
#      'crossStreet': '3 de Febrero',
#      'lat': -34.45471625410005,
#      'lng': -58.54006899940566,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -34.45471625410005,
#        'lng': -58.54006899940566}],
#      'distance': 2480,
#      'postalCode': '1644',
#      'cc': 'AR',
#      'city': 'Victoria',
#      'state': 'Buenos Aires',
#      'country': 'Argentina',
#      'formattedAddress': ['Sta Marina 1250 (3 de Febrero)',
#       '1644 Victoria',
#       'Buenos Aires',
#       'Argentina']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613579668',
#     'hasPerk': False},
#    {'id': '4fd895c7e4b01476c567d570',
#     'name': 'Panadería La Maravilla',
#     'location': {'address': 'Hipólito Yrigoyen 2647',
#      'crossStreet': 'e/ Río de Janeiro y Habana',
#      'lat': -34.502367709470356,
#      'lng': -58.52772233363262,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -34.502367709470356,
#        'lng': -58.52772233363262}],
#      'distance': 3162,
#      'postalCode': 'B1640HGA',
#      'cc': 'AR',
#      'city': 'Martínez',
#      'state': 'Buenos Aires',
#      'country': 'Argentina',
#      'formattedAddress': ['Hipólito Yrigoyen 2647 (e/ Río de Janeiro y Habana)',
#       'B1640HGA Martinez',
#       'Buenos Aires',
#       'Argentina']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613579668',
#     'hasPerk': False},
#    {'id': '507e8d7ce4b06a5eeb553d43',
#     'name': 'Panadería',
#     'location': {'address': 'Hospital “Dr. Antonio A. Cetrángolo"',
#      'lat': -34.522454982167915,
#      'lng': -58.488869310686574,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -34.522454982167915,
#        'lng': -58.488869310686574}],
#      'distance': 6405,
#      'cc': 'AR',
#      'city': 'Vicente López',
#      'state': 'Buenos Aires',
#      'country': 'Argentina',
#      'formattedAddress': ['Hospital “Dr. Antonio A. Cetrángolo"',
#       'Vicente López',
#       'Buenos Aires',
#       'Argentina']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613579668',
#     'hasPerk': False},
#    {'id': '4c08e2d4340720a1c9c28393',
#     'name': 'Panadería La Argentina',
#     'location': {'address': 'Av. Crámer 1891',
#      'crossStreet': 'esq. Mariscal Antonio J. de Sucre',
#      'lat': -34.56670459411594,
#      'lng': -58.45958674558252,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -34.56670459411594,
#        'lng': -58.45958674558252}],
#      'distance': 12008,
#      'postalCode': 'C1428CTA',
#      'cc': 'AR',
#      'city': 'Buenos Aires',
#      'state': 'Buenos Aires C.F.',
#      'country': 'Argentina',
#      'formattedAddress': ['Av. Crámer 1891 (esq. Mariscal Antonio J. de Sucre)',
#       'C1428CTA Buenos Aires',
#       'Buenos Aires C.F.',
#       'Argentina']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613579668',
#     'hasPerk': False},
#    {'id': '591876f32bf9a936dea916f3',
#     'name': 'Panadería La Dorada',
#     'location': {'address': 'Av. Centenario 128',
#      'lat': -34.473172,
#      'lng': -58.51375,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -34.473172,
#        'lng': -58.51375}],
#      'distance': 1172,
#      'postalCode': 'B1642',
#      'cc': 'AR',
#      'city': 'San Isidro',
#      'state': 'Buenos Aires',
#      'country': 'Argentina',
#      'formattedAddress': ['Av. Centenario 128',
#       'B1642 San Isidro',
#       'Buenos Aires',
#       'Argentina']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613579668',
#     'hasPerk': False},
#    {'id': '5815f39338faf1fd6a94615d',
#     'name': 'Panadería Don Manuel',
#     'location': {'address': 'Avenida Presidente Teniente General Juan Domingo Perón 1037',
#      'lat': -34.44021,
#      'lng': -58.556366,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -34.44021,
#        'lng': -58.556366}],
#      'distance': 4653,
#      'postalCode': 'B1646',
#      'cc': 'AR',
#      'city': 'San Fernando',
#      'state': 'Buenos Aires',
#      'country': 'Argentina',
#      'formattedAddress': ['Avenida Presidente Teniente General Juan Domingo Perón 1037',
#       'B1646 San Fernando',
#       'Buenos Aires',
#       'Argentina']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613579668',
#     'hasPerk': False},
#    {'id': '4e760047d22d80eb3371f663',
#     'name': 'Panadería Alvear',
#     'location': {'address': '25 de Mayo 1214',
#      'crossStreet': 'esq. Constitución',
#      'lat': -34.439446337991136,
#      'lng': -58.55908314507369,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -34.439446337991136,
#        'lng': -58.55908314507369}],
#      'distance': 4871,
#      'postalCode': '1646',
#      'cc': 'AR',
#      'city': 'San Fernando',
#      'state': 'Buenos Aires',
#      'country': 'Argentina',
#      'formattedAddress': ['25 de Mayo 1214 (esq. Constitución)',
#       '1646 san fernando',
#       'Buenos Aires',
#       'Argentina']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613579668',
#     'hasPerk': False},
#    {'id': '4b804aa2f964a520e16430e3',
#     'name': 'Panadería La Argentina',
#     'location': {'address': 'Amenábar 1503',
#      'crossStreet': 'esq. Virrey Olaguer y Feliú',
#      'lat': -34.568361,
#      'lng': -58.453306,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -34.568361,
#        'lng': -58.453306}],
#      'distance': 12467,
#      'postalCode': 'C1426AKC',
#      'cc': 'AR',
#      'city': 'Colegiales',
#      'state': 'Buenos Aires C.F.',
#      'country': 'Argentina',
#      'formattedAddress': ['Amenábar 1503 (esq. Virrey Olaguer y Feliú)',
#       'C1426AKC Colegiales',
#       'Buenos Aires C.F.',
#       'Argentina']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613579668',
#     'hasPerk': False}]}}

# %% [markdown]
# # Make the DataFrame

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                                       name  \
# 0  4cdc19ed22bd721e5a3ff947                           Panadería Beccar
# 1  5d555f1e29e8f70008204566                                  Panaderia
# 2  4c07f824bbc676b095cb45d5  PANADERIA - CONFITERIA LA NUEVA ESPERANZA
# 3  4fd895c7e4b01476c567d570                     Panadería La Maravilla
# 4  507e8d7ce4b06a5eeb553d43                                  Panadería
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1613579668    False
# 1  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1613579668    False
# 2  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1613579668    False
# 3  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1613579668    False
# 4  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1613579668    False
#
#                        location.address  location.lat  location.lng  \
# 0                        9 de julio 473    -34.468558    -58.510715
# 1                                   NaN    -34.474884    -58.530518
# 2                       Sta Marina 1250    -34.454716    -58.540069
# 3                Hipólito Yrigoyen 2647    -34.502368    -58.527722
# 4  Hospital “Dr. Antonio A. Cetrángolo"    -34.522455    -58.488869
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': -34.4685575420237...               1568
# 1  [{'label': 'display', 'lat': -34.474884, 'lng'...                383
# 2  [{'label': 'display', 'lat': -34.4547162541000...               2480
# 3  [{'label': 'display', 'lat': -34.5023677094703...               3162
# 4  [{'label': 'display', 'lat': -34.5224549821679...               6405
#
#   location.postalCode location.cc  location.city location.state  \
# 0                1642          AR     San Isidro   Buenos Aires
# 1               B1642          AR     San Isidro   Buenos Aires
# 2                1644          AR       Victoria   Buenos Aires
# 3            B1640HGA          AR       Martínez   Buenos Aires
# 4                 NaN          AR  Vicente López   Buenos Aires
#
#   location.country                          location.formattedAddress  \
# 0        Argentina  [9 de julio 473, 1642 San Isidro, Buenos Aires...
# 1        Argentina        [B1642 San Isidro, Buenos Aires, Argentina]
# 2        Argentina  [Sta Marina 1250 (3 de Febrero), 1644 Victoria...
# 3        Argentina  [Hipólito Yrigoyen 2647 (e/ Río de Janeiro y H...
# 4        Argentina  [Hospital “Dr. Antonio A. Cetrángolo", Vicente...
#
#          location.crossStreet
# 0                         NaN
# 1                         NaN
# 2                3 de Febrero
# 3  e/ Río de Janeiro y Habana
# 4                         NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                         name categories  \
# 0                           Panadería Beccar     Bakery
# 1                                  Panaderia     Bakery
# 2  PANADERIA - CONFITERIA LA NUEVA ESPERANZA     Bakery
# 3                     Panadería La Maravilla     Bakery
# 4                                  Panadería     Bakery
# 5                     Panadería La Argentina     Bakery
# 6                        Panadería La Dorada     Bakery
# 7                       Panadería Don Manuel     Bakery
# 8                           Panadería Alvear     Bakery
# 9                     Panadería La Argentina     Bakery
#
#                                              address        lat        lng  \
# 0                                     9 de julio 473 -34.468558 -58.510715
# 1                                                NaN -34.474884 -58.530518
# 2                                    Sta Marina 1250 -34.454716 -58.540069
# 3                             Hipólito Yrigoyen 2647 -34.502368 -58.527722
# 4               Hospital “Dr. Antonio A. Cetrángolo" -34.522455 -58.488869
# 5                                    Av. Crámer 1891 -34.566705 -58.459587
# 6                                 Av. Centenario 128 -34.473172 -58.513750
# 7  Avenida Presidente Teniente General Juan Domin... -34.440210 -58.556366
# 8                                    25 de Mayo 1214 -34.439446 -58.559083
# 9                                      Amenábar 1503 -34.568361 -58.453306
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': -34.4685575420237...      1568       1642  AR
# 1  [{'label': 'display', 'lat': -34.474884, 'lng'...       383      B1642  AR
# 2  [{'label': 'display', 'lat': -34.4547162541000...      2480       1644  AR
# 3  [{'label': 'display', 'lat': -34.5023677094703...      3162   B1640HGA  AR
# 4  [{'label': 'display', 'lat': -34.5224549821679...      6405        NaN  AR
# 5  [{'label': 'display', 'lat': -34.5667045941159...     12008   C1428CTA  AR
# 6  [{'label': 'display', 'lat': -34.473172, 'lng'...      1172      B1642  AR
# 7  [{'label': 'display', 'lat': -34.44021, 'lng':...      4653      B1646  AR
# 8  [{'label': 'display', 'lat': -34.4394463379911...      4871       1646  AR
# 9  [{'label': 'display', 'lat': -34.568361, 'lng'...     12467   C1426AKC  AR
#
#             city              state    country  \
# 0     San Isidro       Buenos Aires  Argentina
# 1     San Isidro       Buenos Aires  Argentina
# 2       Victoria       Buenos Aires  Argentina
# 3       Martínez       Buenos Aires  Argentina
# 4  Vicente López       Buenos Aires  Argentina
# 5   Buenos Aires  Buenos Aires C.F.  Argentina
# 6     San Isidro       Buenos Aires  Argentina
# 7   San Fernando       Buenos Aires  Argentina
# 8   San Fernando       Buenos Aires  Argentina
# 9     Colegiales  Buenos Aires C.F.  Argentina
#
#                                     formattedAddress  \
# 0  [9 de julio 473, 1642 San Isidro, Buenos Aires...
# 1        [B1642 San Isidro, Buenos Aires, Argentina]
# 2  [Sta Marina 1250 (3 de Febrero), 1644 Victoria...
# 3  [Hipólito Yrigoyen 2647 (e/ Río de Janeiro y H...
# 4  [Hospital “Dr. Antonio A. Cetrángolo", Vicente...
# 5  [Av. Crámer 1891 (esq. Mariscal Antonio J. de ...
# 6  [Av. Centenario 128, B1642 San Isidro, Buenos ...
# 7  [Avenida Presidente Teniente General Juan Domi...
# 8  [25 de Mayo 1214 (esq. Constitución), 1646 san...
# 9  [Amenábar 1503 (esq. Virrey Olaguer y Feliú), ...
#
#                          crossStreet                        id
# 0                                NaN  4cdc19ed22bd721e5a3ff947
# 1                                NaN  5d555f1e29e8f70008204566
# 2                       3 de Febrero  4c07f824bbc676b095cb45d5
# 3         e/ Río de Janeiro y Habana  4fd895c7e4b01476c567d570
# 4                                NaN  507e8d7ce4b06a5eeb553d43
# 5  esq. Mariscal Antonio J. de Sucre  4c08e2d4340720a1c9c28393
# 6                                NaN  591876f32bf9a936dea916f3
# 7                                NaN  5815f39338faf1fd6a94615d
# 8                  esq. Constitución  4e760047d22d80eb3371f663
# 9        esq. Virrey Olaguer y Feliú  4b804aa2f964a520e16430e3

# %% [markdown]
# #  Show other bakeries

# %%
dataframe_filtered.name
# Out:
# 0                             Panadería Beccar
# 1                                    Panaderia
# 2    PANADERIA - CONFITERIA LA NUEVA ESPERANZA
# 3                       Panadería La Maravilla
# 4                                    Panadería
# 5                       Panadería La Argentina
# 6                          Panadería La Dorada
# 7                         Panadería Don Manuel
# 8                             Panadería Alvear
# 9                       Panadería La Argentina
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[dataframe_filtered['lat'].mean(), dataframe_filtered['lng'].mean()], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [dataframe_filtered['lat'].mean(),dataframe_filtered['lng'].mean()],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_cb8ecef284a84ad994f441038d2b2b9b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_cb8ecef284a84ad994f441038d2b2b9b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_cb8ecef284a84ad994f441038d2b2b9b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_cb8ecef284a84ad994f441038d2b2b9b%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B-34.49108744198691%2C-58.513998538602586%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20% ...

# %%
dataframe_filtered['lat'].mean()
# Out:
# -34.49108744198691

# %%
dataframe_filtered['lng'].mean()
# Out:
# -58.513998538602586
